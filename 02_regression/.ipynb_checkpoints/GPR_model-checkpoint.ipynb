# %% [markdown]
# ### 導入相關的函式

# %%
# %pylab inline
from numpy import exp, dot, linspace, power, eye, array, sin, cos, pi, diag, log, sum, sqrt
from numpy.linalg import norm, solve, inv, svd, cholesky
from matplotlib.pylab import plt, scatter
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 以類別形式撰寫高斯過程 (Gaussian Process) 的回歸模型

# %% [markdown]
# 模型參數說明：
#  - `X`: 訓練集中的屬性資料
#  - `y`: 訓練集中與 `X` 對應的 Response
#  - `noise_level`: 模型誤差的容忍值，此值必須大於0
#  - `len_scale`: 當模型過於震盪時，可考慮將此值設大一些
#  - Feature Space 與 Covariance Function 在一定的限制之下，應該是可以隨意修改。 (這句好廢話...)
#
# 在不同參數設定之下，此模型能計算 Log-Marginal Likelihood，愈大的 Likelihood 愈好。如此一來，我們能以此值來估測模型的可靠性。

# %%
class GaussianProcessRegression:
    def __init__( self, X, y, noise_level, len_scale = 1 ):
        self.X = X
        self.y = y
        self.noise_level = noise_level
        self.len_scale = len_scale

        self.x_feature = array([self.feature(xi) for xi in self.X])
        self.L = cholesky( self.kerMat(self.X, self.X) + self.noise_level * eye(self.X.size) )
        self.w = solve( self.L.T, solve(  self.L,  self.y ) )
        self.log_marginal_likelihood = - dot(self.y, self.w)/2 - sum( log( diag( self.L ) ) ) - self.X.size*log(2*pi)/2

    def covariance( self, x_1, x_2 ):
        # Squared Exponential covariance function
        l = self.len_scale # l is the length-scale parameter
        return exp( - power(norm(x_1 - x_2)/l, 2  ) * 0.5 )

    def feature( self, x ):
        return array( [ 1, (x-1)*(x-5)/2, x] )
        #return array( [1, sin(x), cos(x)] )

    def kerMat( self, xlist, ylist ):
        ker = []
        for x in xlist:
            ker.append( [self.covariance( self.feature(x), self.feature(y) ) for y in ylist] )
        return array(ker)
    #def fit(self, x, y, noise_level):
    #    L = cholesky( kerMat(x, x) + noise_level * eye(x.size) )
    #    w = solve( L.T, solve( L, y ) )
    #    log_marginal_likelihood = - dot(y, w)/2 - sum( log( diag( L ) ) ) - x.size*log(2*pi)/2
    #    return w, fit_score

    def predict(self, xtest):
        self.xtest = xtest;
        self.f = dot( self.kerMat(self.xtest, self.X), self.w )
        return self.f

    def predict_var(self, xtest):
        self.xtest = xtest;
        self.f = dot( self.kerMat(self.xtest, self.X), self.w )
        v = solve(self.L, self.kerMat(self.X, self.xtest))
        self.var = diag(self.kerMat( self.xtest, self.xtest )) - diag(dot(v.T, v))
        return self.f

# %%
x = linspace(0, 2*pi, 50)
y = sin(x)

# %%
model = GaussianProcessRegression(x, y, noise_level = 0.01, len_scale = 20)

# %%
x_star = linspace(0, 2*pi, 1000)
y_star = model.predict_var(x_star)

# %%
plt.plot(x_star, y_star)
plt.plot(x_star, y_star+100*model.var)
plt.plot(x_star, y_star-100*model.var)
plt.plot(x_star, sin(x_star))
for i in range(x.size):
    plt.scatter( x[i], y[i] )
plt.show()

# %%
def testModel(noise_level, len_scale):
    model = GaussianProcessRegression(x, y, noise_level, len_scale)
    y_star = model.predict(x_star)

    plt.plot(x_star, y_star)
    #plt.plot(x_star, y_star+100*model.var)
    #plt.plot(x_star, y_star-100*model.var)
    plt.plot(x_star, sin(x_star))
    for i in range(x.size):
        plt.scatter( x[i], y[i] )
    plt.show()
    print model.log_marginal_likelihood

# %%
testModel(0.01, 10) # noise_level = 0.01, len_scale = 10
# Out:
# -86.6682351062

# %%
testModel(1, 1) # noise_level = 1, len_scale = 1
# Out:
# -55.4725255116

# %%
testModel(10, 1) # noise_level = 10, len_scale = 1
# Out:
# -106.058176154
